# %%
# file handling is 
file=open('text.txt','r')
for line in file :
    print(line )
# Out:
# i am qaisar
#
# i am studing a data science
#
# i am in peshawar

# %%
file=open('text.txt','r')

print(file.read(12))
# Out:
# i am in pesh

# %%
file=open('text.txt','r')

print(file.readline())
# Out:
# i am in peshawar

# %%
file=open('text.txt','r')

print(file.readline(5))
# Out:
# i am

# %%
# with open('text.txt', 'w') as file:
#     file.write(line)

file=open('text.txt', 'w')
file.write("this is study room")
file.write("i am belong to hangu")
# Out:
# 20

# %%
file=open('text.txt', 'w')
file.write("this is study room")
file.write("i am belong to hangu")
file.close()

# %%
file=open('text.txt', 'r')
print(file.read())
# Out:
# this is study roomi am belong to hangu

# %%
with open('text.txt', 'a') as file:
    file.write("hello i in study room ")

# %%
file =open('text.txt','r')
for line in file :
    print(line )
# Out:
# this is study roomi am belong to hanguhello i in study room

# %%
# Using \n to add a newline character when writing to the file
with open('text.txt', 'a') as file:
    file.write('\nThis is a new line added to the file.')

# %%
file =open('text.txt','r')
for line in file :
    print(line )
# Out:
# this is study roomi am belong to hanguhello i in study room
#
# This is a new line added to the file.
#
# This is a new line added to the file.
