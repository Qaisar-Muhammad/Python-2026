# %% [markdown]
# #variable  and keyword

# %%
# vaiarble is a reserved memory location to store values 
x = 10
y = 5
sum = x + y
print("The sum of", x, "and", y, "is", sum)
# Out:
# The sum of 10 and 5 is 15

# %%
a='welcome to python programming'
type(a)
# Out:
# str

# %%
a= 20
type(a)
# Out:
# int

# %%
print(a)
# Out:
# 20

# %%
#1,2,3,4,5-> integer
#1.5,2.5-> float    
#'hello'-> string
#"hello"-> string
#True, False-> boolean
#[1,2,3,4]-> list
#{'name':'john', 'age':25}-> dictionary
#(1,2,3,4)-> tuple
#{1,2,3,4}-> set
#None-> null
#--- IGNORE ---

# %%
a= 20
print(type(a))
# Out:
# <class 'int'>

# %%
a= 20.34
print(type(a))
# Out:
# <class 'float'>

# %%
a='python '
print(type(a))
# Out:
# <class 'str'>

# %%
a=[1,2,3,4]
print(type(a))
# Out:
# <class 'list'>

# %%
a=(1,2,3,4)
print(type(a))
# Out:
# <class 'tuple'>

# %%
a={'name':'john', 'age':25}
print(type(a))
# Out:
# <class 'dict'>

# %%
#keywords are reserved words in python which have special meaning and purpose
#cannot be used as variable names
import keyword
print(keyword.kwlist)
print(len(keyword.kwlist))
#list of keywords in python in comment
#False, None, True, and, as, assert, async, await, break,   
#class, continue, def, del, elif, else, except, finally, for, 
#from, global, if, import, in, is, lambda, nonlocal, not,
#or, pass, raise, return, try, while, with, yield


# explain like it  it is boolean values True and False
#None is null value
#and, or, not are logical operators
#as is used to create alias while importing modules 
#assert is used for debugging purpose
#async and await are used for asynchronous programming
#break is used to exit from loop
#class is used to define a class
#continue is used to skip current iteration of loop
#def is used to define a function
#del is used to delete a variable or object
#elif, else, if are used for conditional statements
#except, finally, try are used for exception handling
#for, while are used for loops
#from, import, global, nonlocal, is, lambda, pass, raise, return, with, yield
#--- IGNORE ---
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
# 35

# %%
a=True
print(type(a))
# Out:
# <class 'bool'>

# %%
# typecasting is converting one data type to another data type
# implicit typecasting
a= 10
b= 20.5
c= a + b
print(c)
print(type(c))
# explicit typecasting
x= 10   
y= float(x)
print(y)    
print(type(y))
z= str(x)
print(z)    
print(type(z))
#--- IGNORE ---
# Out:
# 30.5
# <class 'float'>
# 10.0
# <class 'float'>
# 10
# <class 'str'>

# %%
a='qaisar'
print(a[0]) # q
print(a[1]) # a
print(a[2]) # i     
print(a[3]) # s
print(a[4]) # a 
print(a[5]) # r
# Out:
# q
# a
# i
# s
# a
# r
